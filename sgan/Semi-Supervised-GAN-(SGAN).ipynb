# %% [markdown]
# <a href="https://colab.research.google.com/github/kartikgill/The-GAN-Book/blob/main/Skill-06/Semi-Supervised-GAN-(SGAN).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import Useful Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm_notebook
# %matplotlib inline

# %%
import tensorflow
print (tensorflow.__version__)
# Out:
# 2.4.1

# %% [markdown]
# # Download and Show data

# %%
from tensorflow.keras.datasets import fashion_mnist, mnist

(trainX, trainY), (testX, testY) = fashion_mnist.load_data()

print('Training data shapes: X=%s, y=%s' % (trainX.shape, trainY.shape))
print('Testing data shapes: X=%s, y=%s' % (testX.shape, testY.shape))


for k in range(9):
    plt.figure(figsize=(10, 7))
    for j in range(9):
        i = np.random.randint(0, 10000)
        plt.subplot(990 + 1 + j)
        plt.imshow(trainX[i], cmap='gray_r')
        #plt.title(trainY[i])
        plt.axis('off')
    plt.show()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 8192/5148 [===============================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 0s 0us/step
# Training data shapes: X=(60000, 28, 28), y=(60000,)
# Testing data shapes: X=(10000, 28, 28), y=(10000,)

# %% [markdown]
# # Ten classes

# %%
set(trainY)

# %% [markdown]
# # data normalization

# %%
trainX = [(image-127.5)/127.5 for image in trainX]
testX = [(image-127.5)/127.5 for image in testX]

trainX = np.reshape(trainX, (60000, 28, 28, 1))
testX = np.reshape(testX, (10000, 28, 28, 1))

print (trainX.shape, testX.shape, trainY.shape, testY.shape)
# Out:
# (60000, 28, 28, 1) (10000, 28, 28, 1) (60000,) (10000,)

# %% [markdown]
# # Define Generator Model

# %%
random_input = tensorflow.keras.layers.Input(shape = 100)

x = tensorflow.keras.layers.Dense(5*5*64)(random_input)
x = tensorflow.keras.layers.Activation('relu')(x)
x = tensorflow.keras.layers.BatchNormalization(momentum=0.8)(x)

x = tensorflow.keras.layers.Reshape((5, 5, 64))(x)

x = tensorflow.keras.layers.Conv2DTranspose(filters=128, kernel_size=(3,3), strides=2)(x)
x = tensorflow.keras.layers.Activation('relu')(x)
x = tensorflow.keras.layers.BatchNormalization(momentum=0.8)(x)

x = tensorflow.keras.layers.Conv2DTranspose(filters=128, kernel_size=(3,3), strides=2)(x)
x = tensorflow.keras.layers.Activation('relu')(x)
x = tensorflow.keras.layers.BatchNormalization(momentum=0.8)(x)

x = tensorflow.keras.layers.Conv2DTranspose(filters=128, kernel_size=(3,3))(x)
x = tensorflow.keras.layers.Activation('relu')(x)

x = tensorflow.keras.layers.Conv2DTranspose(filters=1, kernel_size=(4,4))(x)
generated_image = tensorflow.keras.layers.Activation('tanh')(x)

generator_network = tensorflow.keras.models.Model(inputs=random_input, outputs=generated_image)
generator_network.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 100)]             0
# _________________________________________________________________
# dense (Dense)                (None, 1600)              161600
# _________________________________________________________________
# activation (Activation)      (None, 1600)              0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 1600)              6400
# _________________________________________________________________
# reshape (Reshape)            (None, 5, 5, 64)          0
# _________________________________________________________________
# conv2d_transpose (Conv2DTran (None, 11, 11, 128)       73856
# _________________________________________________________________
# activation_1 (Activation)    (None, 11, 11, 128)       0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 11, 11, 128)       512
# _________________________________________________________________
# conv2d_transpose_1 (Conv2DTr (None, 23, 23, 128)       147584
# _________________________________________________________________
# activation_2 (Activation)    (None, 23, 23, 128)       0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 23, 23, 128)       512
# _________________________________________________________________
# conv2d_transpose_2 (Conv2DTr (None, 25, 25, 128)       147584
# _________________________________________________________________
# activation_3 (Activation)    (None, 25, 25, 128)       0
# _________________________________________________________________
# conv2d_transpose_3 (Conv2DTr (None, 28, 28, 1)         2049
# _________________________________________________________________
# activation_4 (Activation)    (None, 28, 28, 1)         0
# =================================================================
# Total params: 540,097
# Trainable params: 536,385
# Non-trainable params: 3,712
# _________________________________________________________________

# %% [markdown]
# # Define Discriminator

# %%
image_input = tensorflow.keras.layers.Input(shape=(28, 28, 1))

x = tensorflow.keras.layers.Conv2D(filters=128, kernel_size=(3,3), strides=2)(image_input)
x = tensorflow.keras.layers.LeakyReLU(alpha=0.2)(x)
x = tensorflow.keras.layers.BatchNormalization(momentum=0.8)(x)

x = tensorflow.keras.layers.Conv2D(filters=128, kernel_size=(3,3), strides=2)(x)
x = tensorflow.keras.layers.LeakyReLU(alpha=0.2)(x)
x = tensorflow.keras.layers.BatchNormalization(momentum=0.8)(x)

x = tensorflow.keras.layers.Conv2D(filters=128, kernel_size=(3,3))(x)
x = tensorflow.keras.layers.LeakyReLU(alpha=0.2)(x)
x = tensorflow.keras.layers.BatchNormalization(momentum=0.8)(x)

x = tensorflow.keras.layers.Conv2D(filters=128, kernel_size=(4,4))(x)
x = tensorflow.keras.layers.LeakyReLU(alpha=0.2)(x)
x = tensorflow.keras.layers.BatchNormalization(momentum=0.8)(x)

features = tensorflow.keras.layers.Flatten()(x)

d_out1 = tensorflow.keras.layers.Dense(1)(features)
real_vs_fake_output = tensorflow.keras.layers.Activation('sigmoid')(d_out1)

d_out2 = tensorflow.keras.layers.Dense(11)(features)
class_output = tensorflow.keras.layers.Activation('softmax')(d_out2)

discriminator_network = tensorflow.keras.models.Model(inputs=image_input, outputs=[real_vs_fake_output, class_output])

print (discriminator_network.summary())
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 28, 28, 1)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 13, 13, 128)  1280        input_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu (LeakyReLU)         (None, 13, 13, 128)  0           conv2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 13, 13, 128)  512         leaky_re_lu[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 6, 6, 128)    147584      batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 6, 6, 128)    0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 6, 6, 128)    512         leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 4, 4, 128)    147584      batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 4, 4, 128)    0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 4, 4, 128)    512         leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 1, 1, 128)    262272      batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 1, 1, 128)    0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 1, 1, 128)    512         leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 128)          0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1)            129         flatten[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 11)           1419        flatten[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 1)            0           dense_1[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 11)           0           dense_2[0][0]
# ==================================================================================================
# Total params: 562,316
# Trainable params: 561,292
# Non-trainable params: 1,024
# __________________________________________________________________________________________________
# None

# %%
adam_optimizer = tensorflow.keras.optimizers.Adam(learning_rate=0.0001, beta_1=0.5)
discriminator_network.compile(loss=['binary_crossentropy', 'categorical_crossentropy'], optimizer=adam_optimizer,\
                              metrics=['accuracy'], loss_weights=[0.5, 0.5])

# %% [markdown]
# # Define combined Model: SGAN

# %%
discriminator_network.trainable=False

g_output = generator_network(random_input)

d_output = discriminator_network(g_output)

real_vs_fake = d_output[0]
class_output = d_output[1]

ss_gan_model = tensorflow.keras.models.Model(inputs = random_input, outputs=real_vs_fake)
ss_gan_model.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 100)]             0
# _________________________________________________________________
# model (Functional)           (None, 28, 28, 1)         540097
# _________________________________________________________________
# model_1 (Functional)         [(None, 1), (None, 11)]   562316
# =================================================================
# Total params: 1,102,413
# Trainable params: 536,385
# Non-trainable params: 566,028
# _________________________________________________________________

# %% [markdown]
# # Compiling SGAN

# %%
ss_gan_model.compile(loss=['binary_crossentropy'], optimizer=adam_optimizer)

# %% [markdown]
# # Define Utility Functions

# %%
indices = [i for i in range(0, len(trainX))]

def encode_class_input(value):
    x = np.zeros((11))
    x[value] = 1
    return x

def decode_class_input(value):
    return np.where(value==1)[0][0]

def get_random_noise(batch_size, noise_size):
    random_values = np.random.randn(batch_size*noise_size)
    random_noise_batches = np.reshape(random_values, (batch_size, noise_size))
    return random_noise_batches

def get_fake_samples(generator_network, batch_size, noise_size):
    random_noise_batches = get_random_noise(batch_size, noise_size) 
    fake_samples = generator_network.predict_on_batch(random_noise_batches)
    return fake_samples

def get_real_samples(batch_size):
    random_indices = np.random.choice(indices, size=batch_size)
    real_images = trainX[np.array(random_indices),:]
    real_classes = np.array([encode_class_input(x) for x in trainY[np.array(random_indices),]])
    return real_images, real_classes

def get_fake_classes(batch_size):
    fake_classes = []
    for i in range(batch_size):
        fake_class = encode_class_input(10)
        fake_classes.append(fake_class)
    return np.array(fake_classes)

def show_generator_results(generator_network):
    for k in range(9):
        plt.figure(figsize=(9, 6))
        random_noise_batches = get_random_noise(10, noise_size) 
        fake_samples = generator_network.predict_on_batch(random_noise_batches)
        for j in range(9):
            i = j
            plt.subplot(990 + 1 + j)
            plt.imshow(fake_samples[i,:,:,-1], cmap='gray_r')
            plt.axis('off')
        plt.show()
    return

# %% [markdown]
# # Training SGAN

# %%
epochs = 500
batch_size = 100
steps = 500
noise_size = 100

for i in range(0, epochs):
    if (i%5 == 0):
        op = show_generator_results(generator_network)
        #print (op)
    for j in range(steps):
        fake_samples = get_fake_samples(generator_network, batch_size//2, noise_size)
        fake_classes = get_fake_classes(batch_size//2)
        real_samples, real_classes = get_real_samples(batch_size=batch_size//2)

        fake_y = np.zeros((batch_size//2, 1))
        real_y = np.ones((batch_size//2, 1))
        
        input_samples = np.vstack((fake_samples, real_samples))
        class_labels = np.vstack((fake_classes, real_classes))
        output_labels = np.vstack((fake_y, real_y))
        
        # Updating Discriminator weights
        discriminator_network.trainable=True
        loss_d = discriminator_network.train_on_batch(input_samples, [output_labels, class_labels])
        
        noise_batches = get_random_noise(batch_size, noise_size)
        ss_gan_input = noise_batches
        
        # Make the Discriminator belive that these are real samples and calculate loss to train the generator
        ss_gan_output = np.ones((batch_size))
        
        # Updating Generator weights
        discriminator_network.trainable=False
        loss_g = ss_gan_model.train_on_batch(ss_gan_input, ss_gan_output)
        
        if j%50 == 0:
            print ("Epoch:%.0f, Step:%.0f, D-Loss:%.3f, D-Acc:%.3f, D-Acc-Classification:%.3f, G-Loss:%.3f"%\
                   (i,j,loss_d[0],loss_d[3]*100,loss_d[4]*100,loss_g))
# Out:
# Epoch:0, Step:0, D-Loss:1.805, D-Acc:80.000, D-Acc-Classification:4.000, G-Loss:0.784
# Epoch:0, Step:50, D-Loss:0.388, D-Acc:96.000, D-Acc-Classification:84.000, G-Loss:3.382
# Epoch:0, Step:100, D-Loss:0.287, D-Acc:90.000, D-Acc-Classification:87.000, G-Loss:2.939
# Epoch:0, Step:150, D-Loss:0.283, D-Acc:92.000, D-Acc-Classification:89.000, G-Loss:3.567
# Epoch:0, Step:200, D-Loss:0.232, D-Acc:94.000, D-Acc-Classification:89.000, G-Loss:3.301
# Epoch:0, Step:250, D-Loss:0.370, D-Acc:95.000, D-Acc-Classification:85.000, G-Loss:3.579
# Epoch:0, Step:300, D-Loss:0.216, D-Acc:97.000, D-Acc-Classification:88.000, G-Loss:3.899
# Epoch:0, Step:350, D-Loss:0.250, D-Acc:95.000, D-Acc-Classification:86.000, G-Loss:3.823
# Epoch:0, Step:400, D-Loss:0.238, D-Acc:99.000, D-Acc-Classification:88.000, G-Loss:4.513
# Epoch:0, Step:450, D-Loss:0.192, D-Acc:98.000, D-Acc-Classification:92.000, G-Loss:3.608
# Epoch:1, Step:0, D-Loss:0.194, D-Acc:97.000, D-Acc-Classification:94.000, G-Loss:4.898
# Epoch:1, Step:50, D-Loss:0.248, D-Acc:98.000, D-Acc-Classification:86.000, G-Loss:3.116
# Epoch:1, Step:100, D-Loss:0.186, D-Acc:98.000, D-Acc-Classification:89.000, G-Loss:3.571
# Epoch:1, Step:150, D-Loss:0.168, D-Acc:97.000, D-Acc-Classification:94.000, G-Loss:3.845
# Epoch:1, Step:200, D-Loss:0.160, D-Acc:98.000, D-Acc-Classification:91.000, G-Loss:4.038
# Epoch:1, Step:250, D-Loss:0.217, D-Acc:97.000, D-Acc-Classification:88.000, G-Loss:4.157
# Epoch:1, Step:300, D-Loss:0.126, D-Acc:99.000, D-Acc-Classification:93.000, G-Loss:4.308
# Epoch:1, Step:350, D-Loss:0.311, D-Acc:93.000, D-Acc-Classification:85.000, G-Loss:5.023
# Epoch:1, Step:400, D-Loss:0.231, D-Acc:97.000, D-Acc-Classification:89.000, G-Loss:4.518
# Epoch:1, Step:450, D-Loss:0.285, D-Acc:94.000, D-Acc-Classification:87.000, G-Loss:4.689
# Epoch:2, Step:0, D-Loss:0.202, D-Acc:97.000, D-Acc-Classification:92.000, G-Loss:4.248
# Epoch:2, Step:50, D-Loss:0.263, D-Acc:94.000, D-Acc-Classification:90.000, G-Loss:5.392
# Epoch:2, Step:100, D-Loss:0.114, D-Acc:98.000, D-Acc-Classification:96.000, G-Loss:3.518
# Epoch:2, Step:150, D-Loss:0.207, D-Acc:95.000, D-Acc-Classification:92.000, G-Loss:4.759
# Epoch:2, Step:200, D-Loss:0.184, D-Acc:96.000, D-Acc-Classification:92.000, G-Loss:5.735
# Epoch:2, Step:250, D-Loss:0.121, D-Acc:99.000, D-Acc-Classification:93.000, G-Loss:3.914
# Epoch:2, Step:300, D-Loss:0.271, D-Acc:93.000, D-Acc-Classification:87.000, G-Loss:5.220
# Epoch:2, Step:350, D-Loss:0.214, D-Acc:94.000, D-Acc-Classification:90.000, G-Loss:3.621
# Epoch:2, Step:400, D-Loss:0.125, D-Acc:98.000, D-Acc-Classification:93.000, G-Loss:4.543
# Epoch:2, Step:450, D-Loss:0.182, D-Acc:95.000, D-Acc-Classification:94.000, G-Loss:3.576
# Epoch:3, Step:0, D-Loss:0.256, D-Acc:95.000, D-Acc-Classification:89.000, G-Loss:3.582
# Epoch:3, Step:50, D-Loss:0.288, D-Acc:90.000, D-Acc-Classification:89.000, G-Loss:3.359
# Epoch:3, Step:100, D-Loss:0.116, D-Acc:100.000, D-Acc-Classification:94.000, G-Loss:3.851
# Epoch:3, Step:150, D-Loss:0.240, D-Acc:94.000, D-Acc-Classification:88.000, G-Loss:2.439
# Epoch:3, Step:200, D-Loss:0.207, D-Acc:96.000, D-Acc-Classification:92.000, G-Loss:4.058
# Epoch:3, Step:250, D-Loss:0.227, D-Acc:92.000, D-Acc-Classification:90.000, G-Loss:4.493
# Epoch:3, Step:300, D-Loss:0.209, D-Acc:97.000, D-Acc-Classification:90.000, G-Loss:3.730
# Epoch:3, Step:350, D-Loss:0.191, D-Acc:92.000, D-Acc-Classification:92.000, G-Loss:3.696
# Epoch:3, Step:400, D-Loss:0.256, D-Acc:92.000, D-Acc-Classification:88.000, G-Loss:3.543
# Epoch:3, Step:450, D-Loss:0.143, D-Acc:95.000, D-Acc-Classification:95.000, G-Loss:3.464
# Epoch:4, Step:0, D-Loss:0.287, D-Acc:94.000, D-Acc-Classification:90.000, G-Loss:3.242
# Epoch:4, Step:50, D-Loss:0.301, D-Acc:90.000, D-Acc-Classification:87.000, G-Loss:3.625
# Epoch:4, Step:100, D-Loss:0.212, D-Acc:97.000, D-Acc-Classification:94.000, G-Loss:3.973
# Epoch:4, Step:150, D-Loss:0.233, D-Acc:88.000, D-Acc-Classification:85.000, G-Loss:3.224
# Epoch:4, Step:200, D-Loss:0.243, D-Acc:93.000, D-Acc-Classification:91.000, G-Loss:3.454
# Epoch:4, Step:250, D-Loss:0.232, D-Acc:91.000, D-Acc-Classification:92.000, G-Loss:4.361
# Epoch:4, Step:300, D-Loss:0.187, D-Acc:96.000, D-Acc-Classification:91.000, G-Loss:3.479
# Epoch:4, Step:350, D-Loss:0.247, D-Acc:93.000, D-Acc-Classification:91.000, G-Loss:3.011
# Epoch:4, Step:400, D-Loss:0.208, D-Acc:93.000, D-Acc-Classification:91.000, G-Loss:3.232
# Epoch:4, Step:450, D-Loss:0.166, D-Acc:95.000, D-Acc-Classification:92.000, G-Loss:2.662
# Epoch:5, Step:0, D-Loss:0.343, D-Acc:87.000, D-Acc-Classification:84.000, G-Loss:3.207
# Epoch:5, Step:50, D-Loss:0.297, D-Acc:89.000, D-Acc-Classification:88.000, G-Loss:3.354
# Epoch:5, Step:100, D-Loss:0.172, D-Acc:96.000, D-Acc-Classification:93.000, G-Loss:2.756
# Epoch:5, Step:150, D-Loss:0.195, D-Acc:96.000, D-Acc-Classification:92.000, G-Loss:3.056
# Epoch:5, Step:200, D-Loss:0.226, D-Acc:93.000, D-Acc-Classification:91.000, G-Loss:2.844
# Epoch:5, Step:250, D-Loss:0.232, D-Acc:94.000, D-Acc-Classification:87.000, G-Loss:3.073
# Epoch:5, Step:300, D-Loss:0.252, D-Acc:92.000, D-Acc-Classification:92.000, G-Loss:2.845
# Epoch:5, Step:350, D-Loss:0.248, D-Acc:91.000, D-Acc-Classification:91.000, G-Loss:2.804
# Epoch:5, Step:400, D-Loss:0.240, D-Acc:95.000, D-Acc-Classification:90.000, G-Loss:3.809
# Epoch:5, Step:450, D-Loss:0.301, D-Acc:93.000, D-Acc-Classification:90.000, G-Loss:3.802
# Epoch:6, Step:0, D-Loss:0.140, D-Acc:99.000, D-Acc-Classification:94.000, G-Loss:3.360
# Epoch:6, Step:50, D-Loss:0.177, D-Acc:94.000, D-Acc-Classification:91.000, G-Loss:2.505
# Epoch:6, Step:100, D-Loss:0.223, D-Acc:90.000, D-Acc-Classification:92.000, G-Loss:3.538
# Epoch:6, Step:150, D-Loss:0.225, D-Acc:93.000, D-Acc-Classification:90.000, G-Loss:3.695
# Epoch:6, Step:200, D-Loss:0.257, D-Acc:91.000, D-Acc-Classification:88.000, G-Loss:2.802
# Epoch:6, Step:250, D-Loss:0.355, D-Acc:84.000, D-Acc-Classification:85.000, G-Loss:2.903
# Epoch:6, Step:300, D-Loss:0.226, D-Acc:90.000, D-Acc-Classification:92.000, G-Loss:2.583
# Epoch:6, Step:350, D-Loss:0.318, D-Acc:92.000, D-Acc-Classification:87.000, G-Loss:2.844
# Epoch:6, Step:400, D-Loss:0.189, D-Acc:94.000, D-Acc-Classification:90.000, G-Loss:3.080
# Epoch:6, Step:450, D-Loss:0.291, D-Acc:93.000, D-Acc-Classification:90.000, G-Loss:2.536
# Epoch:7, Step:0, D-Loss:0.184, D-Acc:91.000, D-Acc-Classification:91.000, G-Loss:2.859
# Epoch:7, Step:50, D-Loss:0.246, D-Acc:94.000, D-Acc-Classification:90.000, G-Loss:3.781
# Epoch:7, Step:100, D-Loss:0.245, D-Acc:94.000, D-Acc-Classification:91.000, G-Loss:2.585
# Epoch:7, Step:150, D-Loss:0.214, D-Acc:92.000, D-Acc-Classification:92.000, G-Loss:3.197
# Epoch:7, Step:200, D-Loss:0.191, D-Acc:95.000, D-Acc-Classification:94.000, G-Loss:2.550
# Epoch:7, Step:250, D-Loss:0.193, D-Acc:93.000, D-Acc-Classification:92.000, G-Loss:3.344
# Epoch:7, Step:300, D-Loss:0.231, D-Acc:94.000, D-Acc-Classification:92.000, G-Loss:2.109
# Epoch:7, Step:350, D-Loss:0.236, D-Acc:93.000, D-Acc-Classification:92.000, G-Loss:3.182
# Epoch:7, Step:400, D-Loss:0.226, D-Acc:92.000, D-Acc-Classification:90.000, G-Loss:2.805
# Epoch:7, Step:450, D-Loss:0.322, D-Acc:87.000, D-Acc-Classification:85.000, G-Loss:2.053
# Epoch:8, Step:0, D-Loss:0.310, D-Acc:94.000, D-Acc-Classification:88.000, G-Loss:2.876
# Epoch:8, Step:50, D-Loss:0.257, D-Acc:92.000, D-Acc-Classification:87.000, G-Loss:2.862
# Epoch:8, Step:100, D-Loss:0.192, D-Acc:93.000, D-Acc-Classification:91.000, G-Loss:2.629
# Epoch:8, Step:150, D-Loss:0.221, D-Acc:94.000, D-Acc-Classification:93.000, G-Loss:3.363
# Epoch:8, Step:200, D-Loss:0.244, D-Acc:91.000, D-Acc-Classification:88.000, G-Loss:3.614
# Epoch:8, Step:250, D-Loss:0.344, D-Acc:90.000, D-Acc-Classification:89.000, G-Loss:2.500
# Epoch:8, Step:300, D-Loss:0.305, D-Acc:87.000, D-Acc-Classification:90.000, G-Loss:3.083
# Epoch:8, Step:350, D-Loss:0.227, D-Acc:94.000, D-Acc-Classification:93.000, G-Loss:3.026
# Epoch:8, Step:400, D-Loss:0.152, D-Acc:95.000, D-Acc-Classification:92.000, G-Loss:2.765
# Epoch:8, Step:450, D-Loss:0.311, D-Acc:88.000, D-Acc-Classification:85.000, G-Loss:2.560
# Epoch:9, Step:0, D-Loss:0.280, D-Acc:90.000, D-Acc-Classification:89.000, G-Loss:2.393
# Epoch:9, Step:50, D-Loss:0.297, D-Acc:90.000, D-Acc-Classification:89.000, G-Loss:2.632
# Epoch:9, Step:100, D-Loss:0.317, D-Acc:90.000, D-Acc-Classification:87.000, G-Loss:3.714
# Epoch:9, Step:150, D-Loss:0.187, D-Acc:96.000, D-Acc-Classification:93.000, G-Loss:2.060
# Epoch:9, Step:200, D-Loss:0.254, D-Acc:90.000, D-Acc-Classification:88.000, G-Loss:1.801
# Epoch:9, Step:250, D-Loss:0.298, D-Acc:89.000, D-Acc-Classification:88.000, G-Loss:3.027
# Epoch:9, Step:300, D-Loss:0.347, D-Acc:87.000, D-Acc-Classification:85.000, G-Loss:2.162
# Epoch:9, Step:350, D-Loss:0.251, D-Acc:93.000, D-Acc-Classification:92.000, G-Loss:3.057
# Epoch:9, Step:400, D-Loss:0.289, D-Acc:90.000, D-Acc-Classification:87.000, G-Loss:2.844
# Epoch:9, Step:450, D-Loss:0.200, D-Acc:93.000, D-Acc-Classification:93.000, G-Loss:2.258
# Epoch:10, Step:0, D-Loss:0.242, D-Acc:95.000, D-Acc-Classification:92.000, G-Loss:2.447
# Epoch:10, Step:50, D-Loss:0.359, D-Acc:83.000, D-Acc-Classification:85.000, G-Loss:2.191
# Epoch:10, Step:100, D-Loss:0.278, D-Acc:90.000, D-Acc-Classification:90.000, G-Loss:2.009
# Epoch:10, Step:150, D-Loss:0.337, D-Acc:85.000, D-Acc-Classification:86.000, G-Loss:4.275
# Epoch:10, Step:200, D-Loss:0.201, D-Acc:94.000, D-Acc-Classification:93.000, G-Loss:2.461
# Epoch:10, Step:250, D-Loss:0.256, D-Acc:91.000, D-Acc-Classification:89.000, G-Loss:2.528
# Epoch:10, Step:300, D-Loss:0.436, D-Acc:87.000, D-Acc-Classification:79.000, G-Loss:2.694
# Epoch:10, Step:350, D-Loss:0.240, D-Acc:92.000, D-Acc-Classification:92.000, G-Loss:3.421
# Epoch:10, Step:400, D-Loss:0.230, D-Acc:92.000, D-Acc-Classification:92.000, G-Loss:2.230
# Epoch:10, Step:450, D-Loss:0.266, D-Acc:92.000, D-Acc-Classification:87.000, G-Loss:2.077
# Epoch:11, Step:0, D-Loss:0.245, D-Acc:92.000, D-Acc-Classification:88.000, G-Loss:2.492
# Epoch:11, Step:50, D-Loss:0.347, D-Acc:84.000, D-Acc-Classification:86.000, G-Loss:2.266
# Epoch:11, Step:100, D-Loss:0.245, D-Acc:92.000, D-Acc-Classification:92.000, G-Loss:3.049
# Epoch:11, Step:150, D-Loss:0.301, D-Acc:90.000, D-Acc-Classification:90.000, G-Loss:3.071
# Epoch:11, Step:200, D-Loss:0.215, D-Acc:92.000, D-Acc-Classification:93.000, G-Loss:2.725
# Epoch:11, Step:250, D-Loss:0.283, D-Acc:83.000, D-Acc-Classification:89.000, G-Loss:2.603
# Epoch:11, Step:300, D-Loss:0.359, D-Acc:84.000, D-Acc-Classification:88.000, G-Loss:2.967
# Epoch:11, Step:350, D-Loss:0.305, D-Acc:91.000, D-Acc-Classification:87.000, G-Loss:3.058
# Epoch:11, Step:400, D-Loss:0.228, D-Acc:90.000, D-Acc-Classification:92.000, G-Loss:2.017
# Epoch:11, Step:450, D-Loss:0.300, D-Acc:88.000, D-Acc-Classification:87.000, G-Loss:2.142
# Epoch:12, Step:0, D-Loss:0.217, D-Acc:96.000, D-Acc-Classification:93.000, G-Loss:3.068
# Epoch:12, Step:50, D-Loss:0.459, D-Acc:81.000, D-Acc-Classification:80.000, G-Loss:2.841
# Epoch:12, Step:100, D-Loss:0.281, D-Acc:91.000, D-Acc-Classification:90.000, G-Loss:2.474
# Epoch:12, Step:150, D-Loss:0.254, D-Acc:92.000, D-Acc-Classification:92.000, G-Loss:2.984
# Epoch:12, Step:200, D-Loss:0.310, D-Acc:89.000, D-Acc-Classification:87.000, G-Loss:3.348
# Epoch:12, Step:250, D-Loss:0.240, D-Acc:90.000, D-Acc-Classification:89.000, G-Loss:3.213
# Epoch:12, Step:300, D-Loss:0.299, D-Acc:88.000, D-Acc-Classification:88.000, G-Loss:2.800
# Epoch:12, Step:350, D-Loss:0.341, D-Acc:89.000, D-Acc-Classification:89.000, G-Loss:1.611
# Epoch:12, Step:400, D-Loss:0.338, D-Acc:89.000, D-Acc-Classification:90.000, G-Loss:2.241
# Epoch:12, Step:450, D-Loss:0.328, D-Acc:91.000, D-Acc-Classification:90.000, G-Loss:2.728
# Epoch:13, Step:0, D-Loss:0.304, D-Acc:91.000, D-Acc-Classification:90.000, G-Loss:2.283
# Epoch:13, Step:50, D-Loss:0.324, D-Acc:89.000, D-Acc-Classification:83.000, G-Loss:2.689
# Epoch:13, Step:100, D-Loss:0.253, D-Acc:89.000, D-Acc-Classification:92.000, G-Loss:2.237
# Epoch:13, Step:150, D-Loss:0.330, D-Acc:87.000, D-Acc-Classification:88.000, G-Loss:1.953
# Epoch:13, Step:200, D-Loss:0.313, D-Acc:92.000, D-Acc-Classification:89.000, G-Loss:2.326
# Epoch:13, Step:250, D-Loss:0.315, D-Acc:90.000, D-Acc-Classification:88.000, G-Loss:2.750
# Epoch:13, Step:300, D-Loss:0.349, D-Acc:85.000, D-Acc-Classification:88.000, G-Loss:3.397
# Epoch:13, Step:350, D-Loss:0.385, D-Acc:86.000, D-Acc-Classification:80.000, G-Loss:2.376
# Epoch:13, Step:400, D-Loss:0.285, D-Acc:91.000, D-Acc-Classification:88.000, G-Loss:1.736
# Epoch:13, Step:450, D-Loss:0.355, D-Acc:88.000, D-Acc-Classification:84.000, G-Loss:2.343
# Epoch:14, Step:0, D-Loss:0.341, D-Acc:86.000, D-Acc-Classification:90.000, G-Loss:2.407
# Epoch:14, Step:50, D-Loss:0.484, D-Acc:79.000, D-Acc-Classification:77.000, G-Loss:2.076
# Epoch:14, Step:100, D-Loss:0.288, D-Acc:90.000, D-Acc-Classification:88.000, G-Loss:2.469
# Epoch:14, Step:150, D-Loss:0.248, D-Acc:92.000, D-Acc-Classification:87.000, G-Loss:2.060
# Epoch:14, Step:200, D-Loss:0.272, D-Acc:92.000, D-Acc-Classification:90.000, G-Loss:2.365
# Epoch:14, Step:250, D-Loss:0.237, D-Acc:94.000, D-Acc-Classification:89.000, G-Loss:2.513
# Epoch:14, Step:300, D-Loss:0.312, D-Acc:91.000, D-Acc-Classification:87.000, G-Loss:2.451
# Epoch:14, Step:350, D-Loss:0.325, D-Acc:88.000, D-Acc-Classification:87.000, G-Loss:2.206
# Epoch:14, Step:400, D-Loss:0.247, D-Acc:93.000, D-Acc-Classification:88.000, G-Loss:2.426
# Epoch:14, Step:450, D-Loss:0.322, D-Acc:88.000, D-Acc-Classification:83.000, G-Loss:2.683
# Epoch:15, Step:0, D-Loss:0.322, D-Acc:88.000, D-Acc-Classification:90.000, G-Loss:2.196
# Epoch:15, Step:50, D-Loss:0.410, D-Acc:83.000, D-Acc-Classification:87.000, G-Loss:2.721
# Epoch:15, Step:100, D-Loss:0.288, D-Acc:89.000, D-Acc-Classification:88.000, G-Loss:2.941
# Epoch:15, Step:150, D-Loss:0.410, D-Acc:84.000, D-Acc-Classification:82.000, G-Loss:2.844
# Epoch:15, Step:200, D-Loss:0.302, D-Acc:92.000, D-Acc-Classification:87.000, G-Loss:2.698
# Epoch:15, Step:250, D-Loss:0.275, D-Acc:90.000, D-Acc-Classification:90.000, G-Loss:1.688
# Epoch:15, Step:300, D-Loss:0.307, D-Acc:88.000, D-Acc-Classification:90.000, G-Loss:2.331
# Epoch:15, Step:350, D-Loss:0.370, D-Acc:85.000, D-Acc-Classification:83.000, G-Loss:2.769
# Epoch:15, Step:400, D-Loss:0.272, D-Acc:89.000, D-Acc-Classification:89.000, G-Loss:2.538
# Epoch:15, Step:450, D-Loss:0.275, D-Acc:92.000, D-Acc-Classification:88.000, G-Loss:3.342
# Epoch:16, Step:0, D-Loss:0.400, D-Acc:84.000, D-Acc-Classification:84.000, G-Loss:2.258
# Epoch:16, Step:50, D-Loss:0.272, D-Acc:90.000, D-Acc-Classification:88.000, G-Loss:2.131
# Epoch:16, Step:100, D-Loss:0.303, D-Acc:85.000, D-Acc-Classification:87.000, G-Loss:1.907
# Epoch:16, Step:150, D-Loss:0.391, D-Acc:86.000, D-Acc-Classification:84.000, G-Loss:1.976
# Epoch:16, Step:200, D-Loss:0.284, D-Acc:91.000, D-Acc-Classification:91.000, G-Loss:2.370
# Epoch:16, Step:250, D-Loss:0.238, D-Acc:90.000, D-Acc-Classification:92.000, G-Loss:2.322
# Epoch:16, Step:300, D-Loss:0.352, D-Acc:86.000, D-Acc-Classification:87.000, G-Loss:1.882
# Epoch:16, Step:350, D-Loss:0.279, D-Acc:85.000, D-Acc-Classification:89.000, G-Loss:2.226
# Epoch:16, Step:400, D-Loss:0.346, D-Acc:87.000, D-Acc-Classification:83.000, G-Loss:1.484
# Epoch:16, Step:450, D-Loss:0.377, D-Acc:87.000, D-Acc-Classification:79.000, G-Loss:3.146
# Epoch:17, Step:0, D-Loss:0.258, D-Acc:91.000, D-Acc-Classification:91.000, G-Loss:2.707
# Epoch:17, Step:50, D-Loss:0.286, D-Acc:89.000, D-Acc-Classification:88.000, G-Loss:2.949
# Epoch:17, Step:100, D-Loss:0.339, D-Acc:85.000, D-Acc-Classification:84.000, G-Loss:2.717
# Epoch:17, Step:150, D-Loss:0.278, D-Acc:89.000, D-Acc-Classification:89.000, G-Loss:2.238
# Epoch:17, Step:200, D-Loss:0.294, D-Acc:90.000, D-Acc-Classification:90.000, G-Loss:2.235
# Epoch:17, Step:250, D-Loss:0.279, D-Acc:89.000, D-Acc-Classification:92.000, G-Loss:2.361
# Epoch:17, Step:300, D-Loss:0.407, D-Acc:84.000, D-Acc-Classification:85.000, G-Loss:2.280
# Epoch:17, Step:350, D-Loss:0.392, D-Acc:84.000, D-Acc-Classification:83.000, G-Loss:2.264
# Epoch:17, Step:400, D-Loss:0.311, D-Acc:91.000, D-Acc-Classification:85.000, G-Loss:3.124
# Epoch:17, Step:450, D-Loss:0.215, D-Acc:91.000, D-Acc-Classification:92.000, G-Loss:2.928
# Epoch:18, Step:0, D-Loss:0.256, D-Acc:91.000, D-Acc-Classification:89.000, G-Loss:3.407
# Epoch:18, Step:50, D-Loss:0.283, D-Acc:89.000, D-Acc-Classification:88.000, G-Loss:2.067
# Epoch:18, Step:100, D-Loss:0.335, D-Acc:89.000, D-Acc-Classification:85.000, G-Loss:1.944
# Epoch:18, Step:150, D-Loss:0.303, D-Acc:89.000, D-Acc-Classification:89.000, G-Loss:2.402
# Epoch:18, Step:200, D-Loss:0.302, D-Acc:88.000, D-Acc-Classification:88.000, G-Loss:1.919
# Epoch:18, Step:250, D-Loss:0.352, D-Acc:87.000, D-Acc-Classification:86.000, G-Loss:2.918
# Epoch:18, Step:300, D-Loss:0.196, D-Acc:93.000, D-Acc-Classification:96.000, G-Loss:2.973
# Epoch:18, Step:350, D-Loss:0.365, D-Acc:86.000, D-Acc-Classification:86.000, G-Loss:2.407
# Epoch:18, Step:400, D-Loss:0.318, D-Acc:88.000, D-Acc-Classification:86.000, G-Loss:2.668
# Epoch:18, Step:450, D-Loss:0.295, D-Acc:89.000, D-Acc-Classification:88.000, G-Loss:2.273
# Epoch:19, Step:0, D-Loss:0.340, D-Acc:89.000, D-Acc-Classification:87.000, G-Loss:2.799
# Epoch:19, Step:50, D-Loss:0.288, D-Acc:87.000, D-Acc-Classification:88.000, G-Loss:2.559
# Epoch:19, Step:100, D-Loss:0.324, D-Acc:87.000, D-Acc-Classification:86.000, G-Loss:1.813
# Epoch:19, Step:150, D-Loss:0.264, D-Acc:92.000, D-Acc-Classification:89.000, G-Loss:3.346
# Epoch:19, Step:200, D-Loss:0.376, D-Acc:88.000, D-Acc-Classification:84.000, G-Loss:1.676
# Epoch:19, Step:250, D-Loss:0.329, D-Acc:83.000, D-Acc-Classification:89.000, G-Loss:1.993
# Epoch:19, Step:300, D-Loss:0.304, D-Acc:89.000, D-Acc-Classification:83.000, G-Loss:2.336
# Epoch:19, Step:350, D-Loss:0.375, D-Acc:79.000, D-Acc-Classification:82.000, G-Loss:2.656
# Epoch:19, Step:400, D-Loss:0.283, D-Acc:87.000, D-Acc-Classification:88.000, G-Loss:1.973
# Epoch:19, Step:450, D-Loss:0.331, D-Acc:86.000, D-Acc-Classification:91.000, G-Loss:1.985
# Epoch:20, Step:0, D-Loss:0.329, D-Acc:87.000, D-Acc-Classification:87.000, G-Loss:2.495
# Epoch:20, Step:50, D-Loss:0.370, D-Acc:85.000, D-Acc-Classification:82.000, G-Loss:3.028
# Epoch:20, Step:100, D-Loss:0.314, D-Acc:90.000, D-Acc-Classification:85.000, G-Loss:2.493
# Epoch:20, Step:150, D-Loss:0.306, D-Acc:90.000, D-Acc-Classification:87.000, G-Loss:1.436
# Epoch:20, Step:200, D-Loss:0.265, D-Acc:89.000, D-Acc-Classification:91.000, G-Loss:2.179
# Epoch:20, Step:250, D-Loss:0.270, D-Acc:92.000, D-Acc-Classification:87.000, G-Loss:2.054
# Epoch:20, Step:300, D-Loss:0.400, D-Acc:85.000, D-Acc-Classification:84.000, G-Loss:1.417
# Epoch:20, Step:350, D-Loss:0.352, D-Acc:88.000, D-Acc-Classification:83.000, G-Loss:1.488
# Epoch:20, Step:400, D-Loss:0.345, D-Acc:89.000, D-Acc-Classification:88.000, G-Loss:2.128
# Epoch:20, Step:450, D-Loss:0.455, D-Acc:78.000, D-Acc-Classification:81.000, G-Loss:2.121
# Epoch:21, Step:0, D-Loss:0.364, D-Acc:84.000, D-Acc-Classification:84.000, G-Loss:1.436
# Epoch:21, Step:50, D-Loss:0.327, D-Acc:83.000, D-Acc-Classification:85.000, G-Loss:2.261
# Epoch:21, Step:100, D-Loss:0.322, D-Acc:82.000, D-Acc-Classification:81.000, G-Loss:1.985
# Epoch:21, Step:150, D-Loss:0.267, D-Acc:89.000, D-Acc-Classification:89.000, G-Loss:2.071
# Epoch:21, Step:200, D-Loss:0.377, D-Acc:86.000, D-Acc-Classification:83.000, G-Loss:2.656
# Epoch:21, Step:250, D-Loss:0.269, D-Acc:88.000, D-Acc-Classification:90.000, G-Loss:2.864
# Epoch:21, Step:300, D-Loss:0.352, D-Acc:88.000, D-Acc-Classification:85.000, G-Loss:1.856
# Epoch:21, Step:350, D-Loss:0.368, D-Acc:83.000, D-Acc-Classification:81.000, G-Loss:2.623
# Epoch:21, Step:400, D-Loss:0.253, D-Acc:92.000, D-Acc-Classification:87.000, G-Loss:2.702
# Epoch:21, Step:450, D-Loss:0.379, D-Acc:83.000, D-Acc-Classification:83.000, G-Loss:1.975
# Epoch:22, Step:0, D-Loss:0.315, D-Acc:89.000, D-Acc-Classification:88.000, G-Loss:2.266
# Epoch:22, Step:50, D-Loss:0.378, D-Acc:88.000, D-Acc-Classification:83.000, G-Loss:2.354
# Epoch:22, Step:100, D-Loss:0.344, D-Acc:86.000, D-Acc-Classification:84.000, G-Loss:2.412
# Epoch:22, Step:150, D-Loss:0.233, D-Acc:91.000, D-Acc-Classification:94.000, G-Loss:2.967
# Epoch:22, Step:200, D-Loss:0.346, D-Acc:87.000, D-Acc-Classification:83.000, G-Loss:2.323
# Epoch:22, Step:250, D-Loss:0.400, D-Acc:80.000, D-Acc-Classification:84.000, G-Loss:1.489
# Epoch:22, Step:300, D-Loss:0.325, D-Acc:88.000, D-Acc-Classification:82.000, G-Loss:1.672
# Epoch:22, Step:350, D-Loss:0.184, D-Acc:96.000, D-Acc-Classification:96.000, G-Loss:1.714
# Epoch:22, Step:400, D-Loss:0.357, D-Acc:87.000, D-Acc-Classification:83.000, G-Loss:1.284
# Epoch:22, Step:450, D-Loss:0.246, D-Acc:90.000, D-Acc-Classification:92.000, G-Loss:2.832
# Epoch:23, Step:0, D-Loss:0.326, D-Acc:84.000, D-Acc-Classification:86.000, G-Loss:1.811
# Epoch:23, Step:50, D-Loss:0.395, D-Acc:85.000, D-Acc-Classification:82.000, G-Loss:2.752
# Epoch:23, Step:100, D-Loss:0.294, D-Acc:87.000, D-Acc-Classification:90.000, G-Loss:1.765
# Epoch:23, Step:150, D-Loss:0.407, D-Acc:84.000, D-Acc-Classification:78.000, G-Loss:2.113
# Epoch:23, Step:200, D-Loss:0.275, D-Acc:91.000, D-Acc-Classification:91.000, G-Loss:2.412
# Epoch:23, Step:250, D-Loss:0.290, D-Acc:90.000, D-Acc-Classification:88.000, G-Loss:2.661
# Epoch:23, Step:300, D-Loss:0.252, D-Acc:95.000, D-Acc-Classification:88.000, G-Loss:3.014
# Epoch:23, Step:350, D-Loss:0.331, D-Acc:91.000, D-Acc-Classification:88.000, G-Loss:3.167
# Epoch:23, Step:400, D-Loss:0.264, D-Acc:89.000, D-Acc-Classification:91.000, G-Loss:3.633
# Epoch:23, Step:450, D-Loss:0.286, D-Acc:90.000, D-Acc-Classification:89.000, G-Loss:2.241
# Epoch:24, Step:0, D-Loss:0.347, D-Acc:84.000, D-Acc-Classification:80.000, G-Loss:2.565
# Epoch:24, Step:50, D-Loss:0.292, D-Acc:88.000, D-Acc-Classification:87.000, G-Loss:2.258
# Epoch:24, Step:100, D-Loss:0.418, D-Acc:84.000, D-Acc-Classification:80.000, G-Loss:1.928
# Epoch:24, Step:150, D-Loss:0.247, D-Acc:91.000, D-Acc-Classification:91.000, G-Loss:2.382
# Epoch:24, Step:200, D-Loss:0.274, D-Acc:91.000, D-Acc-Classification:90.000, G-Loss:2.312
# Epoch:24, Step:250, D-Loss:0.355, D-Acc:86.000, D-Acc-Classification:85.000, G-Loss:2.203
# Epoch:24, Step:300, D-Loss:0.237, D-Acc:89.000, D-Acc-Classification:93.000, G-Loss:2.132
# Epoch:24, Step:350, D-Loss:0.325, D-Acc:88.000, D-Acc-Classification:87.000, G-Loss:1.576
# Epoch:24, Step:400, D-Loss:0.437, D-Acc:82.000, D-Acc-Classification:83.000, G-Loss:1.330
# Epoch:24, Step:450, D-Loss:0.286, D-Acc:92.000, D-Acc-Classification:92.000, G-Loss:3.042
# Epoch:25, Step:0, D-Loss:0.310, D-Acc:85.000, D-Acc-Classification:86.000, G-Loss:1.862
# Epoch:25, Step:50, D-Loss:0.313, D-Acc:88.000, D-Acc-Classification:87.000, G-Loss:2.413
# Epoch:25, Step:100, D-Loss:0.335, D-Acc:87.000, D-Acc-Classification:88.000, G-Loss:2.645
# Epoch:25, Step:150, D-Loss:0.296, D-Acc:84.000, D-Acc-Classification:86.000, G-Loss:2.441
# Epoch:25, Step:200, D-Loss:0.308, D-Acc:85.000, D-Acc-Classification:87.000, G-Loss:2.279
# Epoch:25, Step:250, D-Loss:0.304, D-Acc:90.000, D-Acc-Classification:90.000, G-Loss:1.852
# Epoch:25, Step:300, D-Loss:0.384, D-Acc:85.000, D-Acc-Classification:85.000, G-Loss:2.723
# Epoch:25, Step:350, D-Loss:0.325, D-Acc:89.000, D-Acc-Classification:87.000, G-Loss:2.906
# Epoch:25, Step:400, D-Loss:0.314, D-Acc:86.000, D-Acc-Classification:88.000, G-Loss:2.404
# Epoch:25, Step:450, D-Loss:0.346, D-Acc:86.000, D-Acc-Classification:86.000, G-Loss:1.163
# Epoch:26, Step:0, D-Loss:0.342, D-Acc:88.000, D-Acc-Classification:87.000, G-Loss:2.192
# Epoch:26, Step:50, D-Loss:0.376, D-Acc:82.000, D-Acc-Classification:84.000, G-Loss:1.631
# Epoch:26, Step:100, D-Loss:0.352, D-Acc:87.000, D-Acc-Classification:84.000, G-Loss:2.266
# Epoch:26, Step:150, D-Loss:0.362, D-Acc:87.000, D-Acc-Classification:89.000, G-Loss:2.128
# Epoch:26, Step:200, D-Loss:0.385, D-Acc:84.000, D-Acc-Classification:84.000, G-Loss:1.860
# Epoch:26, Step:250, D-Loss:0.358, D-Acc:90.000, D-Acc-Classification:85.000, G-Loss:1.972
# Epoch:26, Step:300, D-Loss:0.403, D-Acc:83.000, D-Acc-Classification:79.000, G-Loss:1.311
# Epoch:26, Step:350, D-Loss:0.299, D-Acc:93.000, D-Acc-Classification:89.000, G-Loss:0.892
# Epoch:26, Step:400, D-Loss:0.235, D-Acc:91.000, D-Acc-Classification:92.000, G-Loss:1.922
# Epoch:26, Step:450, D-Loss:0.339, D-Acc:82.000, D-Acc-Classification:85.000, G-Loss:2.871
# Epoch:27, Step:0, D-Loss:0.435, D-Acc:83.000, D-Acc-Classification:77.000, G-Loss:4.020
# Epoch:27, Step:50, D-Loss:0.369, D-Acc:85.000, D-Acc-Classification:84.000, G-Loss:2.226
# Epoch:27, Step:100, D-Loss:0.303, D-Acc:87.000, D-Acc-Classification:88.000, G-Loss:2.178
# Epoch:27, Step:150, D-Loss:0.327, D-Acc:82.000, D-Acc-Classification:88.000, G-Loss:2.699
# Epoch:27, Step:200, D-Loss:0.307, D-Acc:87.000, D-Acc-Classification:86.000, G-Loss:2.593
# Epoch:27, Step:250, D-Loss:0.357, D-Acc:87.000, D-Acc-Classification:85.000, G-Loss:2.059
# Epoch:27, Step:300, D-Loss:0.302, D-Acc:86.000, D-Acc-Classification:87.000, G-Loss:2.972
# Epoch:27, Step:350, D-Loss:0.271, D-Acc:90.000, D-Acc-Classification:88.000, G-Loss:1.761
# Epoch:27, Step:400, D-Loss:0.362, D-Acc:89.000, D-Acc-Classification:85.000, G-Loss:1.431
# Epoch:27, Step:450, D-Loss:0.440, D-Acc:79.000, D-Acc-Classification:83.000, G-Loss:2.925
# Epoch:28, Step:0, D-Loss:0.402, D-Acc:84.000, D-Acc-Classification:86.000, G-Loss:3.072
# Epoch:28, Step:50, D-Loss:0.350, D-Acc:84.000, D-Acc-Classification:84.000, G-Loss:1.443
# Epoch:28, Step:100, D-Loss:0.356, D-Acc:85.000, D-Acc-Classification:84.000, G-Loss:2.817
# Epoch:28, Step:150, D-Loss:0.298, D-Acc:89.000, D-Acc-Classification:88.000, G-Loss:1.817
# Epoch:28, Step:200, D-Loss:0.397, D-Acc:86.000, D-Acc-Classification:84.000, G-Loss:2.704
# Epoch:28, Step:250, D-Loss:0.293, D-Acc:94.000, D-Acc-Classification:90.000, G-Loss:1.908
# Epoch:28, Step:300, D-Loss:0.306, D-Acc:91.000, D-Acc-Classification:89.000, G-Loss:2.035
# Epoch:28, Step:350, D-Loss:0.375, D-Acc:85.000, D-Acc-Classification:84.000, G-Loss:2.023
# Epoch:28, Step:400, D-Loss:0.417, D-Acc:84.000, D-Acc-Classification:78.000, G-Loss:2.218
# Epoch:28, Step:450, D-Loss:0.374, D-Acc:83.000, D-Acc-Classification:82.000, G-Loss:1.863
# Epoch:29, Step:0, D-Loss:0.346, D-Acc:84.000, D-Acc-Classification:87.000, G-Loss:2.060
# Epoch:29, Step:50, D-Loss:0.361, D-Acc:87.000, D-Acc-Classification:87.000, G-Loss:1.918
# Epoch:29, Step:100, D-Loss:0.375, D-Acc:83.000, D-Acc-Classification:86.000, G-Loss:2.832
# Epoch:29, Step:150, D-Loss:0.356, D-Acc:81.000, D-Acc-Classification:80.000, G-Loss:1.849
# Epoch:29, Step:200, D-Loss:0.439, D-Acc:83.000, D-Acc-Classification:83.000, G-Loss:2.957
# Epoch:29, Step:250, D-Loss:0.397, D-Acc:87.000, D-Acc-Classification:83.000, G-Loss:1.761
# Epoch:29, Step:300, D-Loss:0.302, D-Acc:88.000, D-Acc-Classification:89.000, G-Loss:2.388
# Epoch:29, Step:350, D-Loss:0.257, D-Acc:91.000, D-Acc-Classification:90.000, G-Loss:2.036
# Epoch:29, Step:400, D-Loss:0.311, D-Acc:84.000, D-Acc-Classification:87.000, G-Loss:2.347
# Epoch:29, Step:450, D-Loss:0.372, D-Acc:80.000, D-Acc-Classification:85.000, G-Loss:1.553
# Epoch:30, Step:0, D-Loss:0.297, D-Acc:88.000, D-Acc-Classification:88.000, G-Loss:2.589
# Epoch:30, Step:50, D-Loss:0.311, D-Acc:89.000, D-Acc-Classification:88.000, G-Loss:2.959
# Epoch:30, Step:100, D-Loss:0.345, D-Acc:86.000, D-Acc-Classification:81.000, G-Loss:3.024
# Epoch:30, Step:150, D-Loss:0.432, D-Acc:80.000, D-Acc-Classification:83.000, G-Loss:2.168
# Epoch:30, Step:200, D-Loss:0.432, D-Acc:82.000, D-Acc-Classification:78.000, G-Loss:1.827
# Epoch:30, Step:250, D-Loss:0.371, D-Acc:83.000, D-Acc-Classification:80.000, G-Loss:2.467
# Epoch:30, Step:300, D-Loss:0.462, D-Acc:83.000, D-Acc-Classification:80.000, G-Loss:1.524
# Epoch:30, Step:350, D-Loss:0.355, D-Acc:86.000, D-Acc-Classification:89.000, G-Loss:2.173
# Epoch:30, Step:400, D-Loss:0.333, D-Acc:84.000, D-Acc-Classification:87.000, G-Loss:2.151
# Epoch:30, Step:450, D-Loss:0.358, D-Acc:88.000, D-Acc-Classification:85.000, G-Loss:2.033
# Epoch:31, Step:0, D-Loss:0.308, D-Acc:89.000, D-Acc-Classification:90.000, G-Loss:1.934
# Epoch:31, Step:50, D-Loss:0.313, D-Acc:90.000, D-Acc-Classification:87.000, G-Loss:1.981
# Epoch:31, Step:100, D-Loss:0.411, D-Acc:84.000, D-Acc-Classification:81.000, G-Loss:2.384
# Epoch:31, Step:150, D-Loss:0.301, D-Acc:90.000, D-Acc-Classification:90.000, G-Loss:2.359
# Epoch:31, Step:200, D-Loss:0.316, D-Acc:89.000, D-Acc-Classification:89.000, G-Loss:1.636
# Epoch:31, Step:250, D-Loss:0.412, D-Acc:83.000, D-Acc-Classification:86.000, G-Loss:1.901
# Epoch:31, Step:300, D-Loss:0.430, D-Acc:83.000, D-Acc-Classification:79.000, G-Loss:2.685
# Epoch:31, Step:350, D-Loss:0.301, D-Acc:89.000, D-Acc-Classification:88.000, G-Loss:3.008
# Epoch:31, Step:400, D-Loss:0.355, D-Acc:83.000, D-Acc-Classification:84.000, G-Loss:2.325
# Epoch:31, Step:450, D-Loss:0.372, D-Acc:85.000, D-Acc-Classification:85.000, G-Loss:1.853
# Epoch:32, Step:0, D-Loss:0.333, D-Acc:87.000, D-Acc-Classification:84.000, G-Loss:2.184
# Epoch:32, Step:50, D-Loss:0.367, D-Acc:82.000, D-Acc-Classification:84.000, G-Loss:1.834
# Epoch:32, Step:100, D-Loss:0.313, D-Acc:91.000, D-Acc-Classification:85.000, G-Loss:1.149
# Epoch:32, Step:150, D-Loss:0.324, D-Acc:80.000, D-Acc-Classification:90.000, G-Loss:2.226
# Epoch:32, Step:200, D-Loss:0.461, D-Acc:84.000, D-Acc-Classification:84.000, G-Loss:2.806
# Epoch:32, Step:250, D-Loss:0.376, D-Acc:85.000, D-Acc-Classification:81.000, G-Loss:2.590
# Epoch:32, Step:300, D-Loss:0.486, D-Acc:77.000, D-Acc-Classification:79.000, G-Loss:2.162
# Epoch:32, Step:350, D-Loss:0.353, D-Acc:84.000, D-Acc-Classification:83.000, G-Loss:1.815
# Epoch:32, Step:400, D-Loss:0.376, D-Acc:84.000, D-Acc-Classification:83.000, G-Loss:2.416
# Epoch:32, Step:450, D-Loss:0.380, D-Acc:87.000, D-Acc-Classification:84.000, G-Loss:1.885
# Epoch:33, Step:0, D-Loss:0.327, D-Acc:89.000, D-Acc-Classification:86.000, G-Loss:2.637
# Epoch:33, Step:50, D-Loss:0.295, D-Acc:90.000, D-Acc-Classification:85.000, G-Loss:1.999
# Epoch:33, Step:100, D-Loss:0.289, D-Acc:90.000, D-Acc-Classification:87.000, G-Loss:2.582
# Epoch:33, Step:150, D-Loss:0.271, D-Acc:91.000, D-Acc-Classification:91.000, G-Loss:1.887
# Epoch:33, Step:200, D-Loss:0.360, D-Acc:89.000, D-Acc-Classification:86.000, G-Loss:1.672
# Epoch:33, Step:250, D-Loss:0.329, D-Acc:89.000, D-Acc-Classification:85.000, G-Loss:2.330
# Epoch:33, Step:300, D-Loss:0.329, D-Acc:88.000, D-Acc-Classification:84.000, G-Loss:1.999
# Epoch:33, Step:350, D-Loss:0.312, D-Acc:88.000, D-Acc-Classification:86.000, G-Loss:1.874
# Epoch:33, Step:400, D-Loss:0.362, D-Acc:83.000, D-Acc-Classification:85.000, G-Loss:2.369
# Epoch:33, Step:450, D-Loss:0.363, D-Acc:89.000, D-Acc-Classification:85.000, G-Loss:2.883
# Epoch:34, Step:0, D-Loss:0.407, D-Acc:81.000, D-Acc-Classification:79.000, G-Loss:1.953
# Epoch:34, Step:50, D-Loss:0.363, D-Acc:84.000, D-Acc-Classification:85.000, G-Loss:2.199
# Epoch:34, Step:100, D-Loss:0.301, D-Acc:88.000, D-Acc-Classification:86.000, G-Loss:2.835
# Epoch:34, Step:150, D-Loss:0.370, D-Acc:90.000, D-Acc-Classification:89.000, G-Loss:1.885
# Epoch:34, Step:200, D-Loss:0.440, D-Acc:79.000, D-Acc-Classification:78.000, G-Loss:1.797
# Epoch:34, Step:250, D-Loss:0.462, D-Acc:79.000, D-Acc-Classification:78.000, G-Loss:0.924
# Epoch:34, Step:300, D-Loss:0.256, D-Acc:93.000, D-Acc-Classification:91.000, G-Loss:2.239
# Epoch:34, Step:350, D-Loss:0.299, D-Acc:91.000, D-Acc-Classification:87.000, G-Loss:2.816
# Epoch:34, Step:400, D-Loss:0.302, D-Acc:84.000, D-Acc-Classification:87.000, G-Loss:2.113
# Epoch:34, Step:450, D-Loss:0.371, D-Acc:83.000, D-Acc-Classification:81.000, G-Loss:1.932
# Epoch:35, Step:0, D-Loss:0.465, D-Acc:84.000, D-Acc-Classification:81.000, G-Loss:2.761
# Epoch:35, Step:50, D-Loss:0.372, D-Acc:87.000, D-Acc-Classification:86.000, G-Loss:2.374
# Epoch:35, Step:100, D-Loss:0.411, D-Acc:84.000, D-Acc-Classification:81.000, G-Loss:2.535
# Epoch:35, Step:150, D-Loss:0.321, D-Acc:88.000, D-Acc-Classification:87.000, G-Loss:2.410
# Epoch:35, Step:200, D-Loss:0.365, D-Acc:82.000, D-Acc-Classification:81.000, G-Loss:1.786
# Epoch:35, Step:250, D-Loss:0.370, D-Acc:80.000, D-Acc-Classification:83.000, G-Loss:2.180
# Epoch:35, Step:300, D-Loss:0.399, D-Acc:83.000, D-Acc-Classification:86.000, G-Loss:1.498
# Epoch:35, Step:350, D-Loss:0.330, D-Acc:86.000, D-Acc-Classification:85.000, G-Loss:1.698
# Epoch:35, Step:400, D-Loss:0.284, D-Acc:90.000, D-Acc-Classification:91.000, G-Loss:2.201
# Epoch:35, Step:450, D-Loss:0.450, D-Acc:79.000, D-Acc-Classification:76.000, G-Loss:1.699
# Epoch:36, Step:0, D-Loss:0.271, D-Acc:92.000, D-Acc-Classification:87.000, G-Loss:2.327
# Epoch:36, Step:50, D-Loss:0.417, D-Acc:83.000, D-Acc-Classification:84.000, G-Loss:1.721
# Epoch:36, Step:100, D-Loss:0.332, D-Acc:87.000, D-Acc-Classification:87.000, G-Loss:2.199
# Epoch:36, Step:150, D-Loss:0.395, D-Acc:80.000, D-Acc-Classification:85.000, G-Loss:1.873
# Epoch:36, Step:200, D-Loss:0.503, D-Acc:75.000, D-Acc-Classification:74.000, G-Loss:2.153
# Epoch:36, Step:250, D-Loss:0.426, D-Acc:81.000, D-Acc-Classification:81.000, G-Loss:1.810
# Epoch:36, Step:300, D-Loss:0.464, D-Acc:78.000, D-Acc-Classification:78.000, G-Loss:3.100
# Epoch:36, Step:350, D-Loss:0.339, D-Acc:91.000, D-Acc-Classification:84.000, G-Loss:2.691
# Epoch:36, Step:400, D-Loss:0.348, D-Acc:86.000, D-Acc-Classification:86.000, G-Loss:2.361
# Epoch:36, Step:450, D-Loss:0.261, D-Acc:89.000, D-Acc-Classification:89.000, G-Loss:1.812
# Epoch:37, Step:0, D-Loss:0.360, D-Acc:86.000, D-Acc-Classification:82.000, G-Loss:1.356
# Epoch:37, Step:50, D-Loss:0.328, D-Acc:85.000, D-Acc-Classification:88.000, G-Loss:2.804
# Epoch:37, Step:100, D-Loss:0.298, D-Acc:92.000, D-Acc-Classification:90.000, G-Loss:2.328
# Epoch:37, Step:150, D-Loss:0.514, D-Acc:80.000, D-Acc-Classification:82.000, G-Loss:1.874
# Epoch:37, Step:200, D-Loss:0.315, D-Acc:86.000, D-Acc-Classification:89.000, G-Loss:2.043
# Epoch:37, Step:250, D-Loss:0.443, D-Acc:80.000, D-Acc-Classification:77.000, G-Loss:2.122
# Epoch:37, Step:300, D-Loss:0.327, D-Acc:86.000, D-Acc-Classification:86.000, G-Loss:2.298
# Epoch:37, Step:350, D-Loss:0.272, D-Acc:86.000, D-Acc-Classification:88.000, G-Loss:2.748
# Epoch:37, Step:400, D-Loss:0.372, D-Acc:83.000, D-Acc-Classification:84.000, G-Loss:2.415
# Epoch:37, Step:450, D-Loss:0.351, D-Acc:85.000, D-Acc-Classification:87.000, G-Loss:2.296
# Epoch:38, Step:0, D-Loss:0.444, D-Acc:79.000, D-Acc-Classification:85.000, G-Loss:1.420
# Epoch:38, Step:50, D-Loss:0.380, D-Acc:82.000, D-Acc-Classification:85.000, G-Loss:2.482
# Epoch:38, Step:100, D-Loss:0.352, D-Acc:86.000, D-Acc-Classification:86.000, G-Loss:2.230
# Epoch:38, Step:150, D-Loss:0.374, D-Acc:82.000, D-Acc-Classification:82.000, G-Loss:1.965
# Epoch:38, Step:200, D-Loss:0.329, D-Acc:86.000, D-Acc-Classification:85.000, G-Loss:1.946
# Epoch:38, Step:250, D-Loss:0.426, D-Acc:80.000, D-Acc-Classification:79.000, G-Loss:1.238
# Epoch:38, Step:300, D-Loss:0.392, D-Acc:84.000, D-Acc-Classification:83.000, G-Loss:1.725
# Epoch:38, Step:350, D-Loss:0.330, D-Acc:87.000, D-Acc-Classification:88.000, G-Loss:2.819
# Epoch:38, Step:400, D-Loss:0.345, D-Acc:85.000, D-Acc-Classification:88.000, G-Loss:2.693
# Epoch:38, Step:450, D-Loss:0.432, D-Acc:82.000, D-Acc-Classification:83.000, G-Loss:2.097
# Epoch:39, Step:0, D-Loss:0.278, D-Acc:88.000, D-Acc-Classification:89.000, G-Loss:1.764
# Epoch:39, Step:50, D-Loss:0.328, D-Acc:89.000, D-Acc-Classification:90.000, G-Loss:3.070
# Epoch:39, Step:100, D-Loss:0.363, D-Acc:82.000, D-Acc-Classification:84.000, G-Loss:3.058
# Epoch:39, Step:150, D-Loss:0.326, D-Acc:83.000, D-Acc-Classification:86.000, G-Loss:2.139
# Epoch:39, Step:200, D-Loss:0.257, D-Acc:91.000, D-Acc-Classification:93.000, G-Loss:2.224
# Epoch:39, Step:250, D-Loss:0.362, D-Acc:84.000, D-Acc-Classification:85.000, G-Loss:1.864
# Epoch:39, Step:300, D-Loss:0.496, D-Acc:78.000, D-Acc-Classification:81.000, G-Loss:2.679
# Epoch:39, Step:350, D-Loss:0.396, D-Acc:81.000, D-Acc-Classification:83.000, G-Loss:2.567
# Epoch:39, Step:400, D-Loss:0.319, D-Acc:86.000, D-Acc-Classification:85.000, G-Loss:1.468
# Epoch:39, Step:450, D-Loss:0.406, D-Acc:82.000, D-Acc-Classification:80.000, G-Loss:2.045
# Epoch:40, Step:0, D-Loss:0.377, D-Acc:81.000, D-Acc-Classification:84.000, G-Loss:1.790
# Epoch:40, Step:50, D-Loss:0.393, D-Acc:82.000, D-Acc-Classification:80.000, G-Loss:1.682
# Epoch:40, Step:100, D-Loss:0.486, D-Acc:78.000, D-Acc-Classification:84.000, G-Loss:1.400
# Epoch:40, Step:150, D-Loss:0.414, D-Acc:81.000, D-Acc-Classification:81.000, G-Loss:2.239
# Epoch:40, Step:200, D-Loss:0.417, D-Acc:86.000, D-Acc-Classification:86.000, G-Loss:2.126
# Epoch:40, Step:250, D-Loss:0.301, D-Acc:86.000, D-Acc-Classification:86.000, G-Loss:1.421
# Epoch:40, Step:300, D-Loss:0.356, D-Acc:84.000, D-Acc-Classification:87.000, G-Loss:2.010
# Epoch:40, Step:350, D-Loss:0.385, D-Acc:86.000, D-Acc-Classification:83.000, G-Loss:2.425
# Epoch:40, Step:400, D-Loss:0.379, D-Acc:80.000, D-Acc-Classification:85.000, G-Loss:1.086
# Epoch:40, Step:450, D-Loss:0.385, D-Acc:84.000, D-Acc-Classification:87.000, G-Loss:2.480
# Epoch:41, Step:0, D-Loss:0.346, D-Acc:84.000, D-Acc-Classification:85.000, G-Loss:1.979
# Epoch:41, Step:50, D-Loss:0.317, D-Acc:87.000, D-Acc-Classification:86.000, G-Loss:1.898
# Epoch:41, Step:100, D-Loss:0.331, D-Acc:85.000, D-Acc-Classification:87.000, G-Loss:1.553
# Epoch:41, Step:150, D-Loss:0.368, D-Acc:83.000, D-Acc-Classification:85.000, G-Loss:1.397
# Epoch:41, Step:200, D-Loss:0.324, D-Acc:93.000, D-Acc-Classification:88.000, G-Loss:2.034
# Epoch:41, Step:250, D-Loss:0.468, D-Acc:83.000, D-Acc-Classification:78.000, G-Loss:2.063
# Epoch:41, Step:300, D-Loss:0.217, D-Acc:91.000, D-Acc-Classification:95.000, G-Loss:2.051
# Epoch:41, Step:350, D-Loss:0.398, D-Acc:83.000, D-Acc-Classification:82.000, G-Loss:1.944
# Epoch:41, Step:400, D-Loss:0.380, D-Acc:83.000, D-Acc-Classification:80.000, G-Loss:2.518
# Epoch:41, Step:450, D-Loss:0.459, D-Acc:76.000, D-Acc-Classification:79.000, G-Loss:1.930
# Epoch:42, Step:0, D-Loss:0.384, D-Acc:86.000, D-Acc-Classification:83.000, G-Loss:1.725
# Epoch:42, Step:50, D-Loss:0.321, D-Acc:87.000, D-Acc-Classification:85.000, G-Loss:2.106
# Epoch:42, Step:100, D-Loss:0.317, D-Acc:87.000, D-Acc-Classification:85.000, G-Loss:1.961
# Epoch:42, Step:150, D-Loss:0.395, D-Acc:83.000, D-Acc-Classification:84.000, G-Loss:2.123
# Epoch:42, Step:200, D-Loss:0.402, D-Acc:84.000, D-Acc-Classification:80.000, G-Loss:1.775
# Epoch:42, Step:250, D-Loss:0.301, D-Acc:85.000, D-Acc-Classification:87.000, G-Loss:1.805
# Epoch:42, Step:300, D-Loss:0.429, D-Acc:81.000, D-Acc-Classification:82.000, G-Loss:2.639
# Epoch:42, Step:350, D-Loss:0.365, D-Acc:85.000, D-Acc-Classification:85.000, G-Loss:1.767
# Epoch:42, Step:400, D-Loss:0.308, D-Acc:89.000, D-Acc-Classification:85.000, G-Loss:2.886
# Epoch:42, Step:450, D-Loss:0.315, D-Acc:90.000, D-Acc-Classification:86.000, G-Loss:1.602
# Epoch:43, Step:0, D-Loss:0.348, D-Acc:82.000, D-Acc-Classification:86.000, G-Loss:1.978
# Epoch:43, Step:50, D-Loss:0.338, D-Acc:86.000, D-Acc-Classification:86.000, G-Loss:2.242
# Epoch:43, Step:100, D-Loss:0.364, D-Acc:84.000, D-Acc-Classification:83.000, G-Loss:1.695
# Epoch:43, Step:150, D-Loss:0.339, D-Acc:82.000, D-Acc-Classification:85.000, G-Loss:1.873
# Epoch:43, Step:200, D-Loss:0.390, D-Acc:81.000, D-Acc-Classification:83.000, G-Loss:2.186
# Epoch:43, Step:250, D-Loss:0.369, D-Acc:79.000, D-Acc-Classification:84.000, G-Loss:2.736
# Epoch:43, Step:300, D-Loss:0.364, D-Acc:88.000, D-Acc-Classification:88.000, G-Loss:1.571
# Epoch:43, Step:350, D-Loss:0.309, D-Acc:90.000, D-Acc-Classification:87.000, G-Loss:1.831
# Epoch:43, Step:400, D-Loss:0.385, D-Acc:83.000, D-Acc-Classification:86.000, G-Loss:2.373
# Epoch:43, Step:450, D-Loss:0.281, D-Acc:92.000, D-Acc-Classification:86.000, G-Loss:2.542
# Epoch:44, Step:0, D-Loss:0.248, D-Acc:91.000, D-Acc-Classification:93.000, G-Loss:2.170
# Epoch:44, Step:50, D-Loss:0.415, D-Acc:82.000, D-Acc-Classification:83.000, G-Loss:2.394
# Epoch:44, Step:100, D-Loss:0.322, D-Acc:89.000, D-Acc-Classification:83.000, G-Loss:1.773
# Epoch:44, Step:150, D-Loss:0.439, D-Acc:86.000, D-Acc-Classification:83.000, G-Loss:2.395
# Epoch:44, Step:200, D-Loss:0.415, D-Acc:80.000, D-Acc-Classification:82.000, G-Loss:2.650
# Epoch:44, Step:250, D-Loss:0.390, D-Acc:80.000, D-Acc-Classification:78.000, G-Loss:1.911
# Epoch:44, Step:300, D-Loss:0.418, D-Acc:75.000, D-Acc-Classification:80.000, G-Loss:1.082
# Epoch:44, Step:350, D-Loss:0.420, D-Acc:84.000, D-Acc-Classification:87.000, G-Loss:2.561
# Epoch:44, Step:400, D-Loss:0.296, D-Acc:86.000, D-Acc-Classification:91.000, G-Loss:2.434
# Epoch:44, Step:450, D-Loss:0.416, D-Acc:81.000, D-Acc-Classification:82.000, G-Loss:2.581
# Epoch:45, Step:0, D-Loss:0.404, D-Acc:81.000, D-Acc-Classification:86.000, G-Loss:1.996
# Epoch:45, Step:50, D-Loss:0.235, D-Acc:88.000, D-Acc-Classification:92.000, G-Loss:2.248
# Epoch:45, Step:100, D-Loss:0.337, D-Acc:88.000, D-Acc-Classification:90.000, G-Loss:1.849
# Epoch:45, Step:150, D-Loss:0.257, D-Acc:89.000, D-Acc-Classification:93.000, G-Loss:1.864
# Epoch:45, Step:200, D-Loss:0.283, D-Acc:91.000, D-Acc-Classification:87.000, G-Loss:2.104
# Epoch:45, Step:250, D-Loss:0.343, D-Acc:84.000, D-Acc-Classification:83.000, G-Loss:2.385
# Epoch:45, Step:300, D-Loss:0.393, D-Acc:78.000, D-Acc-Classification:87.000, G-Loss:1.598
# Epoch:45, Step:350, D-Loss:0.352, D-Acc:87.000, D-Acc-Classification:83.000, G-Loss:1.655
# Epoch:45, Step:400, D-Loss:0.355, D-Acc:86.000, D-Acc-Classification:84.000, G-Loss:1.855
# Epoch:45, Step:450, D-Loss:0.286, D-Acc:91.000, D-Acc-Classification:92.000, G-Loss:2.395
# Epoch:46, Step:0, D-Loss:0.373, D-Acc:83.000, D-Acc-Classification:83.000, G-Loss:2.205
# Epoch:46, Step:50, D-Loss:0.442, D-Acc:83.000, D-Acc-Classification:80.000, G-Loss:2.040
# Epoch:46, Step:100, D-Loss:0.385, D-Acc:84.000, D-Acc-Classification:88.000, G-Loss:2.131
# Epoch:46, Step:150, D-Loss:0.393, D-Acc:80.000, D-Acc-Classification:84.000, G-Loss:1.944
# Epoch:46, Step:200, D-Loss:0.353, D-Acc:82.000, D-Acc-Classification:81.000, G-Loss:1.980
# Epoch:46, Step:250, D-Loss:0.364, D-Acc:85.000, D-Acc-Classification:82.000, G-Loss:2.205
# Epoch:46, Step:300, D-Loss:0.326, D-Acc:86.000, D-Acc-Classification:86.000, G-Loss:2.093
# Epoch:46, Step:350, D-Loss:0.340, D-Acc:87.000, D-Acc-Classification:88.000, G-Loss:1.993
# Epoch:46, Step:400, D-Loss:0.450, D-Acc:78.000, D-Acc-Classification:82.000, G-Loss:2.304
# Epoch:46, Step:450, D-Loss:0.362, D-Acc:85.000, D-Acc-Classification:83.000, G-Loss:1.730
# Epoch:47, Step:0, D-Loss:0.300, D-Acc:86.000, D-Acc-Classification:90.000, G-Loss:2.254
# Epoch:47, Step:50, D-Loss:0.365, D-Acc:89.000, D-Acc-Classification:80.000, G-Loss:1.769
# Epoch:47, Step:100, D-Loss:0.385, D-Acc:84.000, D-Acc-Classification:84.000, G-Loss:3.179
# Epoch:47, Step:150, D-Loss:0.310, D-Acc:92.000, D-Acc-Classification:85.000, G-Loss:1.579
# Epoch:47, Step:200, D-Loss:0.251, D-Acc:94.000, D-Acc-Classification:90.000, G-Loss:2.047
# Epoch:47, Step:250, D-Loss:0.313, D-Acc:88.000, D-Acc-Classification:88.000, G-Loss:2.879
# Epoch:47, Step:300, D-Loss:0.383, D-Acc:82.000, D-Acc-Classification:86.000, G-Loss:2.982
# Epoch:47, Step:350, D-Loss:0.340, D-Acc:90.000, D-Acc-Classification:87.000, G-Loss:1.881
# Epoch:47, Step:400, D-Loss:0.359, D-Acc:83.000, D-Acc-Classification:84.000, G-Loss:1.452
# Epoch:47, Step:450, D-Loss:0.371, D-Acc:88.000, D-Acc-Classification:81.000, G-Loss:1.701
# Epoch:48, Step:0, D-Loss:0.469, D-Acc:80.000, D-Acc-Classification:80.000, G-Loss:2.369
# Epoch:48, Step:50, D-Loss:0.362, D-Acc:83.000, D-Acc-Classification:85.000, G-Loss:2.668
# Epoch:48, Step:100, D-Loss:0.395, D-Acc:84.000, D-Acc-Classification:83.000, G-Loss:2.428
# Epoch:48, Step:150, D-Loss:0.336, D-Acc:82.000, D-Acc-Classification:88.000, G-Loss:2.008
# Epoch:48, Step:200, D-Loss:0.331, D-Acc:87.000, D-Acc-Classification:88.000, G-Loss:1.908
# Epoch:48, Step:250, D-Loss:0.381, D-Acc:84.000, D-Acc-Classification:87.000, G-Loss:1.995
# Epoch:48, Step:300, D-Loss:0.288, D-Acc:86.000, D-Acc-Classification:88.000, G-Loss:2.106
# Epoch:48, Step:350, D-Loss:0.267, D-Acc:88.000, D-Acc-Classification:92.000, G-Loss:2.620
# Epoch:48, Step:400, D-Loss:0.376, D-Acc:83.000, D-Acc-Classification:84.000, G-Loss:1.793
# Epoch:48, Step:450, D-Loss:0.419, D-Acc:84.000, D-Acc-Classification:83.000, G-Loss:2.079
# Epoch:49, Step:0, D-Loss:0.316, D-Acc:88.000, D-Acc-Classification:92.000, G-Loss:1.972
# Epoch:49, Step:50, D-Loss:0.304, D-Acc:85.000, D-Acc-Classification:88.000, G-Loss:1.685
# Epoch:49, Step:100, D-Loss:0.507, D-Acc:78.000, D-Acc-Classification:75.000, G-Loss:1.542
# Epoch:49, Step:150, D-Loss:0.314, D-Acc:90.000, D-Acc-Classification:87.000, G-Loss:2.428
# Epoch:49, Step:200, D-Loss:0.328, D-Acc:86.000, D-Acc-Classification:86.000, G-Loss:2.655
# Epoch:49, Step:250, D-Loss:0.444, D-Acc:79.000, D-Acc-Classification:79.000, G-Loss:1.523
# Epoch:49, Step:300, D-Loss:0.265, D-Acc:91.000, D-Acc-Classification:87.000, G-Loss:1.430
# Epoch:49, Step:350, D-Loss:0.420, D-Acc:83.000, D-Acc-Classification:85.000, G-Loss:2.817
# Epoch:49, Step:400, D-Loss:0.427, D-Acc:79.000, D-Acc-Classification:84.000, G-Loss:2.816
# Epoch:49, Step:450, D-Loss:0.310, D-Acc:84.000, D-Acc-Classification:85.000, G-Loss:1.738
# Epoch:50, Step:0, D-Loss:0.320, D-Acc:86.000, D-Acc-Classification:86.000, G-Loss:2.213
# Epoch:50, Step:50, D-Loss:0.347, D-Acc:84.000, D-Acc-Classification:85.000, G-Loss:1.838
# Epoch:50, Step:100, D-Loss:0.396, D-Acc:83.000, D-Acc-Classification:85.000, G-Loss:2.159
# Epoch:50, Step:150, D-Loss:0.440, D-Acc:81.000, D-Acc-Classification:83.000, G-Loss:2.286
# Epoch:50, Step:200, D-Loss:0.433, D-Acc:83.000, D-Acc-Classification:77.000, G-Loss:1.200
# Epoch:50, Step:250, D-Loss:0.403, D-Acc:81.000, D-Acc-Classification:82.000, G-Loss:1.593
# Epoch:50, Step:300, D-Loss:0.320, D-Acc:88.000, D-Acc-Classification:83.000, G-Loss:2.083
# Epoch:50, Step:350, D-Loss:0.382, D-Acc:80.000, D-Acc-Classification:86.000, G-Loss:1.776
# Epoch:50, Step:400, D-Loss:0.388, D-Acc:76.000, D-Acc-Classification:84.000, G-Loss:2.563
# Epoch:50, Step:450, D-Loss:0.302, D-Acc:87.000, D-Acc-Classification:88.000, G-Loss:2.344
# Epoch:51, Step:0, D-Loss:0.394, D-Acc:77.000, D-Acc-Classification:81.000, G-Loss:2.358
# Epoch:51, Step:50, D-Loss:0.382, D-Acc:84.000, D-Acc-Classification:83.000, G-Loss:2.955
# Epoch:51, Step:100, D-Loss:0.302, D-Acc:87.000, D-Acc-Classification:90.000, G-Loss:1.655
# Epoch:51, Step:150, D-Loss:0.375, D-Acc:83.000, D-Acc-Classification:83.000, G-Loss:1.666
# Epoch:51, Step:200, D-Loss:0.404, D-Acc:85.000, D-Acc-Classification:80.000, G-Loss:2.561
# Epoch:51, Step:250, D-Loss:0.420, D-Acc:82.000, D-Acc-Classification:84.000, G-Loss:2.200
# Epoch:51, Step:300, D-Loss:0.347, D-Acc:83.000, D-Acc-Classification:84.000, G-Loss:2.578
# Epoch:51, Step:350, D-Loss:0.378, D-Acc:86.000, D-Acc-Classification:83.000, G-Loss:2.592
# Epoch:51, Step:400, D-Loss:0.382, D-Acc:85.000, D-Acc-Classification:85.000, G-Loss:1.703
# Epoch:51, Step:450, D-Loss:0.472, D-Acc:86.000, D-Acc-Classification:80.000, G-Loss:1.927
# Epoch:52, Step:0, D-Loss:0.364, D-Acc:82.000, D-Acc-Classification:84.000, G-Loss:1.542
# Epoch:52, Step:50, D-Loss:0.308, D-Acc:88.000, D-Acc-Classification:90.000, G-Loss:2.500
# Epoch:52, Step:100, D-Loss:0.362, D-Acc:84.000, D-Acc-Classification:86.000, G-Loss:1.774
# Epoch:52, Step:150, D-Loss:0.384, D-Acc:84.000, D-Acc-Classification:86.000, G-Loss:2.705
# Epoch:52, Step:200, D-Loss:0.340, D-Acc:86.000, D-Acc-Classification:84.000, G-Loss:2.194
# Epoch:52, Step:250, D-Loss:0.417, D-Acc:81.000, D-Acc-Classification:83.000, G-Loss:1.248
# Epoch:52, Step:300, D-Loss:0.385, D-Acc:84.000, D-Acc-Classification:82.000, G-Loss:1.423
# Epoch:52, Step:350, D-Loss:0.404, D-Acc:81.000, D-Acc-Classification:83.000, G-Loss:1.864
# Epoch:52, Step:400, D-Loss:0.341, D-Acc:88.000, D-Acc-Classification:87.000, G-Loss:2.195
# Epoch:52, Step:450, D-Loss:0.343, D-Acc:87.000, D-Acc-Classification:89.000, G-Loss:2.509
# Epoch:53, Step:0, D-Loss:0.396, D-Acc:86.000, D-Acc-Classification:84.000, G-Loss:2.721
# Epoch:53, Step:50, D-Loss:0.402, D-Acc:79.000, D-Acc-Classification:80.000, G-Loss:2.258
# Epoch:53, Step:100, D-Loss:0.387, D-Acc:85.000, D-Acc-Classification:85.000, G-Loss:1.456
# Epoch:53, Step:150, D-Loss:0.429, D-Acc:80.000, D-Acc-Classification:83.000, G-Loss:1.693
# Epoch:53, Step:200, D-Loss:0.403, D-Acc:81.000, D-Acc-Classification:81.000, G-Loss:2.435
# Epoch:53, Step:250, D-Loss:0.426, D-Acc:79.000, D-Acc-Classification:82.000, G-Loss:1.794
# Epoch:53, Step:300, D-Loss:0.332, D-Acc:85.000, D-Acc-Classification:85.000, G-Loss:2.454
# Epoch:53, Step:350, D-Loss:0.420, D-Acc:80.000, D-Acc-Classification:81.000, G-Loss:1.292
# Epoch:53, Step:400, D-Loss:0.374, D-Acc:88.000, D-Acc-Classification:84.000, G-Loss:1.866
# Epoch:53, Step:450, D-Loss:0.329, D-Acc:85.000, D-Acc-Classification:86.000, G-Loss:2.221
# Epoch:54, Step:0, D-Loss:0.362, D-Acc:84.000, D-Acc-Classification:86.000, G-Loss:2.039
# Epoch:54, Step:50, D-Loss:0.371, D-Acc:85.000, D-Acc-Classification:85.000, G-Loss:2.678
# Epoch:54, Step:100, D-Loss:0.302, D-Acc:87.000, D-Acc-Classification:85.000, G-Loss:1.376
# Epoch:54, Step:150, D-Loss:0.332, D-Acc:86.000, D-Acc-Classification:87.000, G-Loss:1.741
# Epoch:54, Step:200, D-Loss:0.327, D-Acc:80.000, D-Acc-Classification:87.000, G-Loss:1.505
# Epoch:54, Step:250, D-Loss:0.383, D-Acc:86.000, D-Acc-Classification:85.000, G-Loss:1.641
# Epoch:54, Step:300, D-Loss:0.398, D-Acc:87.000, D-Acc-Classification:85.000, G-Loss:0.994
# Epoch:54, Step:350, D-Loss:0.324, D-Acc:86.000, D-Acc-Classification:89.000, G-Loss:2.197
# Epoch:54, Step:400, D-Loss:0.348, D-Acc:85.000, D-Acc-Classification:85.000, G-Loss:1.956
# Epoch:54, Step:450, D-Loss:0.569, D-Acc:81.000, D-Acc-Classification:75.000, G-Loss:1.413
# Epoch:55, Step:0, D-Loss:0.481, D-Acc:75.000, D-Acc-Classification:78.000, G-Loss:2.336
# Epoch:55, Step:50, D-Loss:0.375, D-Acc:84.000, D-Acc-Classification:83.000, G-Loss:2.132
# Epoch:55, Step:100, D-Loss:0.320, D-Acc:85.000, D-Acc-Classification:91.000, G-Loss:1.592
# Epoch:55, Step:150, D-Loss:0.459, D-Acc:78.000, D-Acc-Classification:78.000, G-Loss:1.696
# Epoch:55, Step:200, D-Loss:0.285, D-Acc:90.000, D-Acc-Classification:89.000, G-Loss:1.904
# Epoch:55, Step:250, D-Loss:0.365, D-Acc:84.000, D-Acc-Classification:84.000, G-Loss:2.042
# Epoch:55, Step:300, D-Loss:0.371, D-Acc:80.000, D-Acc-Classification:81.000, G-Loss:2.208
# Epoch:55, Step:350, D-Loss:0.388, D-Acc:84.000, D-Acc-Classification:86.000, G-Loss:1.911
# Epoch:55, Step:400, D-Loss:0.368, D-Acc:81.000, D-Acc-Classification:87.000, G-Loss:2.607
# Epoch:55, Step:450, D-Loss:0.282, D-Acc:87.000, D-Acc-Classification:92.000, G-Loss:2.286
# Epoch:56, Step:0, D-Loss:0.288, D-Acc:88.000, D-Acc-Classification:88.000, G-Loss:3.007
# Epoch:56, Step:50, D-Loss:0.346, D-Acc:84.000, D-Acc-Classification:87.000, G-Loss:1.977
# Epoch:56, Step:100, D-Loss:0.359, D-Acc:86.000, D-Acc-Classification:85.000, G-Loss:1.982
# Epoch:56, Step:150, D-Loss:0.349, D-Acc:89.000, D-Acc-Classification:87.000, G-Loss:1.675
# Epoch:56, Step:200, D-Loss:0.318, D-Acc:86.000, D-Acc-Classification:90.000, G-Loss:1.993
# Epoch:56, Step:250, D-Loss:0.322, D-Acc:85.000, D-Acc-Classification:90.000, G-Loss:1.467
# Epoch:56, Step:300, D-Loss:0.329, D-Acc:83.000, D-Acc-Classification:90.000, G-Loss:2.686
# Epoch:56, Step:350, D-Loss:0.458, D-Acc:81.000, D-Acc-Classification:78.000, G-Loss:1.341
# Epoch:56, Step:400, D-Loss:0.419, D-Acc:83.000, D-Acc-Classification:80.000, G-Loss:1.613
# Epoch:56, Step:450, D-Loss:0.408, D-Acc:82.000, D-Acc-Classification:82.000, G-Loss:2.224
# Epoch:57, Step:0, D-Loss:0.380, D-Acc:84.000, D-Acc-Classification:88.000, G-Loss:2.473
# Epoch:57, Step:50, D-Loss:0.356, D-Acc:87.000, D-Acc-Classification:85.000, G-Loss:2.061
# Epoch:57, Step:100, D-Loss:0.352, D-Acc:86.000, D-Acc-Classification:86.000, G-Loss:1.563
# Epoch:57, Step:150, D-Loss:0.415, D-Acc:82.000, D-Acc-Classification:83.000, G-Loss:1.727
# Epoch:57, Step:200, D-Loss:0.464, D-Acc:82.000, D-Acc-Classification:82.000, G-Loss:2.269
# Epoch:57, Step:250, D-Loss:0.417, D-Acc:82.000, D-Acc-Classification:83.000, G-Loss:1.890
# Epoch:57, Step:300, D-Loss:0.303, D-Acc:86.000, D-Acc-Classification:87.000, G-Loss:1.585
# Epoch:57, Step:350, D-Loss:0.338, D-Acc:86.000, D-Acc-Classification:85.000, G-Loss:1.779
# Epoch:57, Step:400, D-Loss:0.427, D-Acc:80.000, D-Acc-Classification:81.000, G-Loss:1.844
# Epoch:57, Step:450, D-Loss:0.347, D-Acc:85.000, D-Acc-Classification:87.000, G-Loss:2.068
# Epoch:58, Step:0, D-Loss:0.275, D-Acc:87.000, D-Acc-Classification:91.000, G-Loss:1.860
# Epoch:58, Step:50, D-Loss:0.497, D-Acc:79.000, D-Acc-Classification:77.000, G-Loss:2.082
# Epoch:58, Step:100, D-Loss:0.486, D-Acc:81.000, D-Acc-Classification:73.000, G-Loss:2.291
# Epoch:58, Step:150, D-Loss:0.298, D-Acc:93.000, D-Acc-Classification:89.000, G-Loss:2.794
# Epoch:58, Step:200, D-Loss:0.375, D-Acc:80.000, D-Acc-Classification:84.000, G-Loss:1.834
# Epoch:58, Step:250, D-Loss:0.450, D-Acc:79.000, D-Acc-Classification:82.000, G-Loss:2.875
# Epoch:58, Step:300, D-Loss:0.357, D-Acc:84.000, D-Acc-Classification:86.000, G-Loss:2.483
# Epoch:58, Step:350, D-Loss:0.329, D-Acc:86.000, D-Acc-Classification:85.000, G-Loss:2.335
# Epoch:58, Step:400, D-Loss:0.319, D-Acc:86.000, D-Acc-Classification:87.000, G-Loss:1.358
# Epoch:58, Step:450, D-Loss:0.315, D-Acc:86.000, D-Acc-Classification:87.000, G-Loss:2.445
# Epoch:59, Step:0, D-Loss:0.391, D-Acc:79.000, D-Acc-Classification:80.000, G-Loss:2.269
# Epoch:59, Step:50, D-Loss:0.456, D-Acc:79.000, D-Acc-Classification:78.000, G-Loss:1.641
# Epoch:59, Step:100, D-Loss:0.264, D-Acc:88.000, D-Acc-Classification:88.000, G-Loss:1.977
# Epoch:59, Step:150, D-Loss:0.288, D-Acc:89.000, D-Acc-Classification:87.000, G-Loss:1.641
# Epoch:59, Step:200, D-Loss:0.442, D-Acc:79.000, D-Acc-Classification:83.000, G-Loss:3.318
# Epoch:59, Step:250, D-Loss:0.341, D-Acc:85.000, D-Acc-Classification:85.000, G-Loss:1.440
# Epoch:59, Step:300, D-Loss:0.315, D-Acc:88.000, D-Acc-Classification:87.000, G-Loss:2.252
# Epoch:59, Step:350, D-Loss:0.431, D-Acc:84.000, D-Acc-Classification:82.000, G-Loss:2.483
# Epoch:59, Step:400, D-Loss:0.300, D-Acc:85.000, D-Acc-Classification:88.000, G-Loss:1.935
# Epoch:59, Step:450, D-Loss:0.373, D-Acc:84.000, D-Acc-Classification:83.000, G-Loss:1.710
# Epoch:60, Step:0, D-Loss:0.348, D-Acc:87.000, D-Acc-Classification:85.000, G-Loss:2.961
# Epoch:60, Step:50, D-Loss:0.340, D-Acc:81.000, D-Acc-Classification:86.000, G-Loss:2.093
# Epoch:60, Step:100, D-Loss:0.336, D-Acc:84.000, D-Acc-Classification:81.000, G-Loss:2.042
# Epoch:60, Step:150, D-Loss:0.390, D-Acc:79.000, D-Acc-Classification:82.000, G-Loss:1.578
# Epoch:60, Step:200, D-Loss:0.401, D-Acc:82.000, D-Acc-Classification:82.000, G-Loss:2.509
# Epoch:60, Step:250, D-Loss:0.284, D-Acc:90.000, D-Acc-Classification:88.000, G-Loss:2.651
# Epoch:60, Step:300, D-Loss:0.321, D-Acc:85.000, D-Acc-Classification:86.000, G-Loss:2.866
# Epoch:60, Step:350, D-Loss:0.399, D-Acc:83.000, D-Acc-Classification:85.000, G-Loss:1.956
# Epoch:60, Step:400, D-Loss:0.370, D-Acc:85.000, D-Acc-Classification:85.000, G-Loss:2.083
# Epoch:60, Step:450, D-Loss:0.320, D-Acc:87.000, D-Acc-Classification:87.000, G-Loss:2.505
# Epoch:61, Step:0, D-Loss:0.388, D-Acc:83.000, D-Acc-Classification:83.000, G-Loss:2.240
# Epoch:61, Step:50, D-Loss:0.345, D-Acc:87.000, D-Acc-Classification:85.000, G-Loss:2.518
# Epoch:61, Step:100, D-Loss:0.403, D-Acc:81.000, D-Acc-Classification:85.000, G-Loss:2.065
# Epoch:61, Step:150, D-Loss:0.365, D-Acc:86.000, D-Acc-Classification:84.000, G-Loss:2.376
# Epoch:61, Step:200, D-Loss:0.526, D-Acc:75.000, D-Acc-Classification:74.000, G-Loss:2.004
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-3073fc29c2ba> in <module>()
#      11         fake_samples = get_fake_samples(generator_network, batch_size//2, noise_size)
#      12         fake_classes = get_fake_classes(batch_size//2)
# ---> 13         real_samples, real_classes = get_real_samples(batch_size=batch_size//2)
#      14
#      15         fake_y = np.zeros((batch_size//2, 1))
#
# <ipython-input-12-c9cbfb77fe07> in get_real_samples(batch_size)
#      20
#      21 def get_real_samples(batch_size):
# ---> 22     random_indices = np.random.choice(indices, size=batch_size)
#      23     real_images = trainX[np.array(random_indices),:]
#      24     real_classes = np.array([encode_class_input(x) for x in trainY[np.array(random_indices),]])
#
# mtrand.pyx in numpy.random.mtrand.RandomState.choice()
#
# <__array_function__ internals> in prod(*args, **kwargs)
#
# KeyboardInterrupt:

# %% [markdown]
# # Results

# %%
for i in range(2):
    show_generator_results(generator_network)
    print("-"*100)
# Out:
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
